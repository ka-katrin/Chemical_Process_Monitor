# %%
#first this split, doing all the work on df , copying that for test.
#later, I want to split differently (18 days test -> 20 %) for when I do feature engineering and comparing the results of both. but for now, a rolling window (->backtesting)
tscv = TimeSeriesSplit(n_splits=5)

# %%
#spalte die time to fault in min ersetzt:??

# %%
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
